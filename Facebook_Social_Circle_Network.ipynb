# %% [markdown]
# <a href="https://colab.research.google.com/github/summerolmstead/Facebook-Social-Circle-Network/blob/main/Facebook_Social_Circle_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Summer Olmstead
#
# Facebook Social Circle Dataset
#
# https://snap.stanford.edu/data/ego-Facebook.html  SNAP Standford University

# %% [markdown]
# # Loading in Dataset File - Into DF

# %%
import pandas as pd
#before i got it to this stage, I personally extracted it from its .gz stage on the hyperlinked website above then added it to the directory here for this runtime
file_path = '/content/facebook_combined.txt'  #path to file in google colab directory

#load the file -> delimiter is a space between the source node column and target node for each row
df = pd.read_csv(file_path, sep=" ", header=None, names=["Source Node", "Target Node"])

#display the first few rows to check the data to make sure it correctly made it into a df
df.head()
# Out:
#    Source Node  Target Node
# 0            0            1
# 1            0            2
# 2            0            3
# 3            0            4
# 4            0            5

# %%
import networkx as nx

#create the graph from df
G = nx.from_pandas_edgelist(df, 'Source Node', 'Target Node')

#check basic information about the graph to see total nodes and edges we are working with
print(f"Graph info: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

#visualizing the graph of facebook social circles - essentially user interactions
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
nx.draw(G, node_size=30, with_labels=False, alpha=0.5)
plt.show()
# Out:
# Graph info: 4039 nodes, 88234 edges

# %% [markdown]
# Wow, it is honestly a beautiful visualization
#
# What the graph info means in our context is -
#
# 4039 nodes -> This represents 4,039 unique users. Each node is a user in the Facebook social network.
#
# 88234 edges -> This represents 88,234 interactions. Each edge signifies a friendship or connection between two users (nodes). This could be a like or a comment on someone else's post intuitively.
#
# So, there are 88,234 unique connections across the 4,039 users in this dataset.

# %%
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(G, k=0.1, iterations=50)  # Adjust `k` for node spacing
nx.draw(G, pos, node_size=30, with_labels=False, alpha=0.5, edge_color='gray')
plt.title("Spring Layout of Facebook Network")
plt.show()

# %%
plt.figure(figsize=(10, 10))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, pos, node_size=30, with_labels=False, alpha=0.5, edge_color='gray')
plt.title("Kamada-Kawai Layout of Facebook Network")
plt.show()
